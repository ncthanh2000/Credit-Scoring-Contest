# %%
import pandas as pd
import numpy as np
import variance_plot as vp

# %%
df = pd.read_excel(r'Data\Final Data.xlsx')
label = df[['id','label']]
df.drop(columns = ['maCv', 'province','district','id','label'], inplace = True)
df = pd.get_dummies(df)

# %%
X = df.copy()

# %%
df_std = X.copy()

from sklearn.preprocessing import StandardScaler
__ = StandardScaler().fit_transform(df_std)
df_std = pd.DataFrame(__,columns=X.columns)
df_std.head(2)
# Out:
#    age_source1  age_source2   FIELD_1   FIELD_2   FIELD_3   FIELD_4   FIELD_5  \
# 0    -1.070616    -1.310032  0.538301  0.556452  0.570538 -0.558827 -0.858978
# 1     1.399484     1.259229  0.538301 -1.550787 -1.155017  0.458393 -0.364953
#
#     FIELD_6  FIELD_11  FIELD_14  ...  FIELD_40_4  FIELD_40_6  FIELD_40_Fill  \
# 0 -0.267037 -0.855889  1.230462  ...   -0.005774    -0.02888       0.452623
# 1  1.875547  1.108072 -0.812703  ...   -0.005774    -0.02888       0.452623
#
#    FIELD_43_0  FIELD_43_5  FIELD_43_A  FIELD_43_B  FIELD_43_C  FIELD_43_D  \
# 0   -0.005774   -0.020821   -0.061762   -0.112205    -0.14646   -0.046598
# 1   -0.005774   -0.020821   -0.061762   -0.112205    -0.14646   -0.046598
#
#    FIELD_43_Fill
# 0        0.20377
# 1        0.20377
#
# [2 rows x 445 columns]

# %%
for i in range(2,len(df_std.columns) + 1):
    df_pca, df_var = vp.pca_transform(df_std, i)
    print(np.sum(df_var))
    if(float(np.sum(df_var)) > 0.8):
        break
    
    #print(df_var.sum())
    #if(df_var.sum() > 0.8):
        #break
# Out:
# 0    0.106295
# dtype: float64
# 0    0.117571
# dtype: float64
# 0    0.12694
# dtype: float64
# 0    0.135031
# dtype: float64
# 0    0.142111
# dtype: float64
# 0    0.148767
# dtype: float64
# 0    0.154511
# dtype: float64
# 0    0.159989
# dtype: float64
# 0    0.165384
# dtype: float64
# 0    0.17074
# dtype: float64
# 0    0.175908
# dtype: float64
# 0    0.181133
# dtype: float64
# 0    0.18621
# dtype: float64
# 0    0.191167
# dtype: float64
# 0    0.196131
# dtype: float64
# 0    0.200937
# dtype: float64
# 0    0.205519
# dtype: float64
# 0    0.210463
# dtype: float64
# 0    0.215168
# dtype: float64
# 0    0.219892
# dtype: float64
# 0    0.224502
# dtype: float64
# 0    0.229026
# dtype: float64
# 0    0.233868
# dtype: float64
# 0    0.238341
# dtype: float64
# 0    0.242903
# dtype: float64
# 0    0.247378
# dtype: float64
# 0    0.251943
# dtype: float64
# 0    0.256369
# dtype: float64
# 0    0.260645
# dtype: float64
# 0    0.264735
# dtype: float64
# ...

# %%
for i in range(270,len(df_std.columns),10):
    df_pca, df_var = vp.pca_transform(df_std, i)
    print(np.sum(df_var))
# Out:
# 0    0.823929
# dtype: float64
# 0    0.845925
# dtype: float64
# 0    0.867428
# dtype: float64
# 0    0.889051
# dtype: float64
# 0    0.910311
# dtype: float64
# 0    0.930496
# dtype: float64
# 0    0.950105
# dtype: float64
# 0    0.967301
# dtype: float64
# 0    0.980841
# dtype: float64
# 0    0.990315
# dtype: float64
# 0    0.996145
# dtype: float64
# 0    0.998776
# dtype: float64
# 0    0.999592
# dtype: float64
# 0    0.999918
# dtype: float64
# 0    0.999996
# dtype: float64
# 0    1.0
# dtype: float64
# 0    1.0
# dtype: float64
# 0    1.0
# dtype: float64

# %%
df_pca, df_var = vp.pca_transform(df_std, 100)

# %%
df_pca = pd.concat([label, df_pca], axis = 1)

# %%
df_pca.to_excel(r'Data\std_pca_100.xlsx', index = False)
