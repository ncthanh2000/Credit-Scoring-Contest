# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import kde_plot_col as k

# %%
df = pd.read_excel(r'Data/Test - Final Data.xlsx')

# %%
df.columns.values
# Out:
# array(['age_source1', 'age_source2', 'FIELD_1', 'FIELD_2', 'FIELD_3',
#        'FIELD_4', 'FIELD_5', 'FIELD_6', 'FIELD_11', 'FIELD_14',
#        'FIELD_15', 'FIELD_16', 'FIELD_18', 'FIELD_19', 'FIELD_20',
#        'FIELD_21', 'FIELD_22', 'FIELD_23', 'FIELD_25', 'FIELD_26',
#        'FIELD_27', 'FIELD_28', 'FIELD_32', 'FIELD_33', 'FIELD_34',
#        'FIELD_35', 'FIELD_38', 'FIELD_41', 'FIELD_42', 'FIELD_44',
#        'FIELD_45', 'FIELD_46', 'FIELD_47', 'FIELD_48', 'FIELD_49',
#        'FIELD_50', 'FIELD_51', 'FIELD_52', 'FIELD_53', 'FIELD_54',
#        'FIELD_55', 'FIELD_56', 'FIELD_57', 'FIELD_7 - AT', 'FIELD_7 - BT',
#        'FIELD_7 - CB', 'FIELD_7 - CC', 'FIELD_7 - CH', 'FIELD_7 - CK',
#        'FIELD_7 - CN', 'FIELD_7 - DK', 'FIELD_7 - DN', 'FIELD_7 - DT',
#        'FIELD_7 - GB', 'FIELD_7 - GD', 'FIELD_7 - HC', 'FIELD_7 - HD',
#        'FIELD_7 - HG', 'FIELD_7 - HK', 'FIELD_7 - HN', 'FIELD_7 - HS',
#        'FIELD_7 - HT', 'FIELD_7 - HX', 'FIELD_7 - KC', 'FIELD_7 - MS',
# ...

# %%
k.kde_col(df, df.columns.values, 2)
